# %%
import pandas as pd
df=pd.read_json("products.json")

# %%
df.head()
# Out:
#         sku                    name               category_id   price  \
# 0  60000019  Trà đen Phúc Long 200g  6906ce5a1440315f50ee4bde   58000
# 1  60000021  Trà đen Phúc Long 500g  6906ce5a1440315f50ee4bde  135000
# 2  60000072   Trà lài hộp giấy 150g  6906ce5a1440315f50ee4bde   75000
# 3  60000075       Trà lài 15 - 200g  6906ce5a1440315f50ee4bde  105000
# 4  60000076       Trà lài 15 - 500g  6906ce5a1440315f50ee4bde  250000
#
#    stock_quantity  is_active             description  \
# 0               0       True  Trà đen Phúc Long 200g
# 1               0       True  Trà đen Phúc Long 500g
# 2               0       True   Trà lài hộp giấy 150g
# 3               0       True       Trà lài 15 - 200g
# 4               0       True       Trà lài 15 - 500g
#
#                                               images  raw_itemNo  \
# 0  [https://s3-hcmc02.higiocloud.vn/images/2022/6...    60000019
# 1  [https://s3-hcmc02.higiocloud.vn/images/2022/6...    60000021
# ...

# %%
df.columns
# Out:
# Index(['sku', 'name', 'category_id', 'price', 'stock_quantity', 'is_active',
#        'description', 'images', 'raw_itemNo', 'raw_id', 'detected_packaged'],
#       dtype='object')

# %%
df.groupby('price')['name'].apply(list)
# Out:
# price
# 15000         [Topping thạch konjac, Topping Thạch Dừa Sợi]
# 20000     [Topping Nhãn (4 trái), Bánh Flan Phúc Long, T...
# 22000                            [Bánh croissant choco 45g]
# 25000     [Topping Đác Cam, Topping Đác Thơm, Bánh crois...
# 30000               [Trà xanh (túi lọc) 2g x 25gói x 20hộp]
# 35000     [Panna Cotta Chanh Dây 120g, Trà xanh Thái Ngu...
# 36000                              [Trà Hoa Hồng (Túi Lọc)]
# 37000     [Trà hồng trà túi lọc 2g x 25gói x 20 hộp, Trà...
# 38000     [Bánh Tiramisu, Bánh mì Phúc Long 170g, Trà ô ...
# 39000     [Cà Phê Đen Đá (L), Bánh Chuối Hạt Dinh Dưỡng,...
# 40000     [Trà Bá Tước (M), Trà Ô Long Quế Hoa (M), Trà ...
# 45000     [Cà Phê Sữa Đá (L), Trà Phúc Long (M), Trà Ô L...
# 49000                                  [Hồng Trà Chanh (L)]
# 50000     [Trà Phúc Long (L), Trà Ô Long (L), Hồng Trà (...
# 55000     [Cà phê Latte (M), Cà phê Cappuccino (M), Trà ...
# 58000     [Trà đen Phúc Long 200g, Trà hương sen mới (lo...
# ...
